# %% [markdown]
# # Heterogeneous treatment effects on MIMIC-II
#
# The previous tutorial estimated a single average effect of arterial-line placement on 28-day mortality.
# Real clinical interventions often help some patients and hurt others; the per-patient effect is the *conditional* average treatment effect, or CATE.
# ehrapy ships three meta-learners that estimate CATE on top of any sklearn-compatible regressor.

# %%
import ehrapy as ep
import ehrdata as ed
import numpy as np
import pandas as pd

edata = ed.dt.mimic_2_preprocessed()
treatment = "aline_flg"
outcome = "day_28_flg"
covariates = ["age", "gender_num", "sapsi_first", "sofa_first", "weight_first", "bmi", "icu_los_day", "sepsis_flg"]
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4b60ee95-0f32-4cd5-be26-b7f92b9ad126'>
#   <div id="a26716de-27dc-44b2-9dd3-e6ca71bb6724" data-root-id="4b60ee95-0f32-4cd5-be26-b7f92b9ad126" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## T-learner &mdash; one model per arm
#
# Fit `μ_1` on the treated subset and `μ_0` on the untreated subset; the CATE for unit `i` is `μ_1(X_i) − μ_0(X_i)`.

# %%
from sklearn.ensemble import GradientBoostingClassifier

est_t = ep.tl.t_learner(
    edata,
    treatment,
    outcome,
    covariates=covariates,
    outcome_model=GradientBoostingClassifier(),
    key_added="cate_t",
)
print(f"average CATE: {est_t.value:.4f}")
# Out:
# average CATE: -0.0106

# %% [markdown]
# :::{admonition} Why a tree-based base learner?
# :class: dropdown
#
# Linear base learners regularise the *additive* part of the model but not the interaction structure that produces heterogeneity.
# Tree-based learners (gradient boosting, random forest) pick up non-linear treatment-by-covariate interactions naturally, which is usually what you want when estimating CATE.
# A linear S-learner will reliably report a flat CATE even when one exists.
# :::

# %% [markdown]
# ## X-learner &mdash; bias-corrected and propensity-weighted
#
# The X-learner first imputes individual treatment effects on each arm using the *other* arm's model, fits a second-stage CATE model per arm, and combines the two with propensity weights.
# More efficient than the T-learner when treatment groups are unbalanced.

# %%
est_x = ep.tl.x_learner(
    edata,
    treatment,
    outcome,
    covariates=covariates,
    outcome_model=GradientBoostingClassifier(),
    cate_model="gradient_boosting",
    key_added="cate_x",
)
print(f"average CATE: {est_x.value:.4f}")
# Out:
# average CATE: -0.0266

# %% [markdown]
# ## Compare the per-patient CATE distributions

# %%
import holoviews as hv

counts_t, edges_t = np.histogram(est_t.params["cate"], bins=40, density=True)
counts_x, edges_x = np.histogram(est_x.params["cate"], bins=40, density=True)
hist_t = hv.Histogram((edges_t, counts_t), kdims="CATE", vdims="density", label="T-learner").opts(
    fill_color="#1f77b4", alpha=0.5, line_alpha=0
)
hist_x = hv.Histogram((edges_x, counts_x), kdims="CATE", vdims="density", label="X-learner").opts(
    fill_color="#d62728", alpha=0.5, line_alpha=0
)
zero = hv.VLine(0).opts(color="black", line_width=1, line_dash="dashed")
(hist_t * hist_x * zero).opts(
    width=520,
    height=320,
    xlabel="Estimated CATE: P(death | line) − P(death | no line)",
    ylabel="Density",
    show_legend=True,
)
# Out:
# :Overlay
#    .Histogram.T_hyphen_minus_learner :Histogram   [CATE]   (density)
#    .Histogram.X_hyphen_minus_learner :Histogram   [CATE]   (density)
#    .VLine.I                          :VLine   [x,y]

# %% [markdown]
# ## Inspect subgroups by severity
#
# Stratifying the per-patient CATE by SOFA score tells us whether sicker patients gain (or lose) more from the intervention.

# %%
cate = est_x.params["cate"]
df = ed.io.to_pandas(edata)
sofa_bins = pd.qcut(
    df.loc[est_x.params["index"], "sofa_first"],
    q=4,
    labels=["Q1 (least sick)", "Q2", "Q3", "Q4 (sickest)"],
)
pd.DataFrame({"sofa_quartile": sofa_bins.values, "cate": cate}).groupby("sofa_quartile", observed=True)["cate"].agg(["mean", "std", "count"])
# Out:
#                      mean       std  count
# sofa_quartile
# Q1 (least sick) -0.011394  0.085449    524
# Q2              -0.021327  0.115993    641
# Q3              -0.020115  0.114909    246
# Q4 (sickest)    -0.062130  0.166724    365

# %% [markdown]
# :::{admonition} What to read off a CATE table
# :class: dropdown
#
# A positive value means the intervention is associated with higher mortality in that subgroup; a negative value means the opposite.
# Watch the SE/standard deviation column: heterogeneity that&rsquo;s smaller than its own uncertainty is not interpretable, no matter how large the point estimate.
# Subgroup analyses are *exploratory* &mdash; treat clinically actionable claims as hypotheses to be tested in a pre-registered analysis or trial.
# :::

# %% [markdown]
# ## Where the CATE was written
#
# Each learner stores the per-patient CATE in `edata.obs` under the key passed to `key_added`, so you can combine it with the rest of ehrapy &mdash; e.g. plot it on top of an existing UMAP.

# %%
edata.obs[["cate_t", "cate_x"]].describe()
# Out:
#             cate_t       cate_x
# count  1776.000000  1776.000000
# mean     -0.010576    -0.026614
# std       0.179542     0.121939
# min      -0.851102    -0.959581
# 25%      -0.033686    -0.052261
# 50%       0.004264    -0.013188
# 75%       0.022109     0.024762
# max       0.718165     0.524273
